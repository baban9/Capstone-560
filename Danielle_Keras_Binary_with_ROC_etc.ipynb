# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
# Out:
# Mounted at /content/gdrive

# %%
data_dir = '/content/gdrive/Shareddrives/ComED Codes and Data/Dataset/Images/'

print(os.listdir(data_dir))
# Out:
# ['With UPC', 'Without UPC']

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt

# %%
image_size = (600, 600)
batch_size = 5

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/gdrive/Shareddrives/ComED Codes and Data/Dataset/Images",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/gdrive/Shareddrives/ComED Codes and Data/Dataset/Images",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 1024 files belonging to 2 classes.
# Using 820 files for training.
# Found 1024 files belonging to 2 classes.
# Using 204 files for validation.

# %%
data_augmentation = keras.Sequential(
    [
        # layers.experimental.preprocessing.RandomFlip("horizontal"),
        # layers.experimental.preprocessing.RandomRotation(0.1),
        layers.experimental.preprocessing.Resizing(128,128)
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
train_ds = train_ds.prefetch(buffer_size=5)
val_ds = val_ds.prefetch(buffer_size=5)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
# keras.utils.plot_model(model, show_shapes=True)

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
epochs = 50

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_Dan_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy",f1_m,precision_m, recall_m],   #can try another loss function type
)
model.fit(train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds)
# Out:
# Epoch 1/50
# 164/164 [==============================] - 12s 61ms/step - loss: 0.0517 - accuracy: 0.9849 - f1_m: 0.9824 - precision_m: 0.9779 - recall_m: 0.9916 - val_loss: 0.9615 - val_accuracy: 0.7353 - val_f1_m: 0.7846 - val_precision_m: 0.8593 - val_recall_m: 0.7565
# Epoch 2/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0169 - accuracy: 0.9908 - f1_m: 0.9906 - precision_m: 0.9897 - recall_m: 0.9952 - val_loss: 0.8558 - val_accuracy: 0.7696 - val_f1_m: 0.8121 - val_precision_m: 0.8537 - val_recall_m: 0.8203
# Epoch 3/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0182 - accuracy: 0.9931 - f1_m: 0.9945 - precision_m: 0.9944 - recall_m: 0.9964 - val_loss: 1.1299 - val_accuracy: 0.7892 - val_f1_m: 0.8579 - val_precision_m: 0.8333 - val_recall_m: 0.9167
# Epoch 4/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0552 - accuracy: 0.9925 - f1_m: 0.9902 - precision_m: 0.9914 - recall_m: 0.9894 - val_loss: 0.8699 - val_accuracy: 0.7696 - val_f1_m: 0.8269 - val_precision_m: 0.8569 - val_recall_m: 0.8325
# Epoch 5/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0334 - accuracy: 0.9905 - f1_m: 0.9938 - precision_m: 0.9953 - recall_m: 0.9938 - val_loss: 0.8924 - val_accuracy: 0.7598 - val_f1_m: 0.8270 - val_precision_m: 0.8146 - val_recall_m: 0.8841
# Epoch 6/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0107 - accuracy: 0.9959 - f1_m: 0.9938 - precision_m: 0.9912 - recall_m: 0.9994 - val_loss: 0.8488 - val_accuracy: 0.7745 - val_f1_m: 0.8183 - val_precision_m: 0.9037 - val_recall_m: 0.7833
# Epoch 7/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0155 - accuracy: 0.9926 - f1_m: 0.9937 - precision_m: 0.9910 - recall_m: 0.9983 - val_loss: 0.7742 - val_accuracy: 0.7843 - val_f1_m: 0.8425 - val_precision_m: 0.8911 - val_recall_m: 0.8407
# Epoch 8/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0108 - accuracy: 0.9952 - f1_m: 0.9963 - precision_m: 0.9988 - recall_m: 0.9943 - val_loss: 1.0700 - val_accuracy: 0.7745 - val_f1_m: 0.8365 - val_precision_m: 0.8289 - val_recall_m: 0.8760
# Epoch 9/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0138 - accuracy: 0.9956 - f1_m: 0.9956 - precision_m: 0.9927 - recall_m: 1.0000 - val_loss: 0.8189 - val_accuracy: 0.7941 - val_f1_m: 0.8562 - val_precision_m: 0.8508 - val_recall_m: 0.8850
# Epoch 10/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0440 - accuracy: 0.9816 - f1_m: 0.9720 - precision_m: 0.9724 - recall_m: 0.9735 - val_loss: 0.9688 - val_accuracy: 0.8186 - val_f1_m: 0.8544 - val_precision_m: 0.8386 - val_recall_m: 0.8959
# Epoch 11/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0030 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.9051 - val_accuracy: 0.8039 - val_f1_m: 0.8567 - val_precision_m: 0.8659 - val_recall_m: 0.8837
# Epoch 12/50
# 164/164 [==============================] - 10s 58ms/step - loss: 7.8875e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 1.0465 - val_accuracy: 0.7990 - val_f1_m: 0.8556 - val_precision_m: 0.8382 - val_recall_m: 0.9085
# Epoch 13/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0023 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.9063 - val_accuracy: 0.8088 - val_f1_m: 0.8647 - val_precision_m: 0.8520 - val_recall_m: 0.9114
# Epoch 14/50
# 164/164 [==============================] - 10s 57ms/step - loss: 6.5644e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.9439 - val_accuracy: 0.8137 - val_f1_m: 0.8623 - val_precision_m: 0.8472 - val_recall_m: 0.9053
# Epoch 15/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0421 - accuracy: 0.9863 - f1_m: 0.9884 - precision_m: 0.9922 - recall_m: 0.9875 - val_loss: 2.0653 - val_accuracy: 0.6176 - val_f1_m: 0.6279 - val_precision_m: 0.8699 - val_recall_m: 0.5179
# Epoch 16/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0758 - accuracy: 0.9694 - f1_m: 0.9760 - precision_m: 0.9801 - recall_m: 0.9806 - val_loss: 0.9104 - val_accuracy: 0.8186 - val_f1_m: 0.8640 - val_precision_m: 0.8772 - val_recall_m: 0.8894
# Epoch 17/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0514 - accuracy: 0.9791 - f1_m: 0.9805 - precision_m: 0.9801 - recall_m: 0.9879 - val_loss: 1.0713 - val_accuracy: 0.7990 - val_f1_m: 0.8608 - val_precision_m: 0.8191 - val_recall_m: 0.9346
# Epoch 18/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.1325 - accuracy: 0.9684 - f1_m: 0.9702 - precision_m: 0.9759 - recall_m: 0.9723 - val_loss: 0.9704 - val_accuracy: 0.8088 - val_f1_m: 0.8624 - val_precision_m: 0.8484 - val_recall_m: 0.9069
# Epoch 19/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0399 - accuracy: 0.9866 - f1_m: 0.9902 - precision_m: 0.9901 - recall_m: 0.9929 - val_loss: 0.8603 - val_accuracy: 0.7598 - val_f1_m: 0.8258 - val_precision_m: 0.8496 - val_recall_m: 0.8443
# Epoch 20/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0183 - accuracy: 0.9970 - f1_m: 0.9951 - precision_m: 0.9926 - recall_m: 1.0000 - val_loss: 0.8940 - val_accuracy: 0.7941 - val_f1_m: 0.8418 - val_precision_m: 0.8533 - val_recall_m: 0.8703
# Epoch 21/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0131 - accuracy: 0.9979 - f1_m: 0.9967 - precision_m: 0.9950 - recall_m: 1.0000 - val_loss: 0.9296 - val_accuracy: 0.7990 - val_f1_m: 0.8459 - val_precision_m: 0.8630 - val_recall_m: 0.8695
# Epoch 22/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0260 - accuracy: 0.9915 - f1_m: 0.9925 - precision_m: 0.9934 - recall_m: 0.9943 - val_loss: 0.9402 - val_accuracy: 0.7990 - val_f1_m: 0.8624 - val_precision_m: 0.8618 - val_recall_m: 0.9037
# Epoch 23/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0037 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.9177 - val_accuracy: 0.7843 - val_f1_m: 0.8330 - val_precision_m: 0.8630 - val_recall_m: 0.8398
# Epoch 24/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0053 - accuracy: 0.9991 - f1_m: 0.9995 - precision_m: 1.0000 - recall_m: 0.9991 - val_loss: 0.8983 - val_accuracy: 0.8039 - val_f1_m: 0.8618 - val_precision_m: 0.8711 - val_recall_m: 0.8890
# Epoch 25/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0077 - accuracy: 0.9982 - f1_m: 0.9987 - precision_m: 0.9978 - recall_m: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.8039 - val_f1_m: 0.8543 - val_precision_m: 0.8423 - val_recall_m: 0.8984
# Epoch 26/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0021 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.9297 - val_accuracy: 0.7598 - val_f1_m: 0.8030 - val_precision_m: 0.8528 - val_recall_m: 0.7862
# Epoch 27/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0029 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 1.0044 - val_accuracy: 0.7745 - val_f1_m: 0.8281 - val_precision_m: 0.8691 - val_recall_m: 0.8256
# Epoch 28/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0026 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 1.0003 - val_accuracy: 0.7892 - val_f1_m: 0.8356 - val_precision_m: 0.8907 - val_recall_m: 0.8301
# Epoch 29/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0077 - accuracy: 0.9975 - f1_m: 0.9982 - precision_m: 0.9987 - recall_m: 0.9983 - val_loss: 0.9488 - val_accuracy: 0.7843 - val_f1_m: 0.8341 - val_precision_m: 0.9020 - val_recall_m: 0.8276
# Epoch 30/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0442 - accuracy: 0.9839 - f1_m: 0.9842 - precision_m: 0.9861 - recall_m: 0.9875 - val_loss: 1.5293 - val_accuracy: 0.8039 - val_f1_m: 0.8614 - val_precision_m: 0.8199 - val_recall_m: 0.9248
# Epoch 31/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0530 - accuracy: 0.9830 - f1_m: 0.9874 - precision_m: 0.9896 - recall_m: 0.9886 - val_loss: 0.8247 - val_accuracy: 0.7843 - val_f1_m: 0.8377 - val_precision_m: 0.8732 - val_recall_m: 0.8569
# Epoch 32/50
# 164/164 [==============================] - 10s 57ms/step - loss: 0.0700 - accuracy: 0.9895 - f1_m: 0.9860 - precision_m: 0.9878 - recall_m: 0.9845 - val_loss: 0.8815 - val_accuracy: 0.8039 - val_f1_m: 0.8377 - val_precision_m: 0.8976 - val_recall_m: 0.8171
# Epoch 33/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0664 - accuracy: 0.9840 - f1_m: 0.9878 - precision_m: 0.9890 - recall_m: 0.9902 - val_loss: 0.7626 - val_accuracy: 0.8186 - val_f1_m: 0.8651 - val_precision_m: 0.8829 - val_recall_m: 0.8703
# Epoch 34/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0088 - accuracy: 0.9974 - f1_m: 0.9981 - precision_m: 1.0000 - recall_m: 0.9968 - val_loss: 0.7221 - val_accuracy: 0.8039 - val_f1_m: 0.8554 - val_precision_m: 0.8988 - val_recall_m: 0.8488
# Epoch 35/50
# 164/164 [==============================] - 10s 58ms/step - loss: 0.0021 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.7779 - val_accuracy: 0.8039 - val_f1_m: 0.8377 - val_precision_m: 0.8943 - val_recall_m: 0.8179
# Epoch 36/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0090 - accuracy: 0.9979 - f1_m: 0.9985 - precision_m: 0.9994 - recall_m: 0.9981 - val_loss: 0.8007 - val_accuracy: 0.8137 - val_f1_m: 0.8659 - val_precision_m: 0.8431 - val_recall_m: 0.9215
# Epoch 37/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0024 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.7787 - val_accuracy: 0.7794 - val_f1_m: 0.8271 - val_precision_m: 0.8618 - val_recall_m: 0.8228
# Epoch 38/50
# 164/164 [==============================] - 10s 60ms/step - loss: 0.0025 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.8090 - val_accuracy: 0.7745 - val_f1_m: 0.8168 - val_precision_m: 0.8533 - val_recall_m: 0.8118
# Epoch 39/50
# 164/164 [==============================] - 10s 59ms/step - loss: 9.9363e-04 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.8271 - val_accuracy: 0.7794 - val_f1_m: 0.8251 - val_precision_m: 0.8573 - val_recall_m: 0.8285
# Epoch 40/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.8486 - val_accuracy: 0.7892 - val_f1_m: 0.8401 - val_precision_m: 0.8488 - val_recall_m: 0.8549
# Epoch 41/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0089 - accuracy: 0.9979 - f1_m: 0.9939 - precision_m: 0.9938 - recall_m: 0.9944 - val_loss: 0.8518 - val_accuracy: 0.8039 - val_f1_m: 0.8646 - val_precision_m: 0.8463 - val_recall_m: 0.9098
# Epoch 42/50
# 164/164 [==============================] - 10s 60ms/step - loss: 0.0081 - accuracy: 0.9969 - f1_m: 0.9983 - precision_m: 1.0000 - recall_m: 0.9969 - val_loss: 0.8702 - val_accuracy: 0.8186 - val_f1_m: 0.8741 - val_precision_m: 0.8898 - val_recall_m: 0.8923
# Epoch 43/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0149 - accuracy: 0.9931 - f1_m: 0.9924 - precision_m: 0.9915 - recall_m: 0.9964 - val_loss: 0.9567 - val_accuracy: 0.7794 - val_f1_m: 0.8455 - val_precision_m: 0.8325 - val_recall_m: 0.8984
# Epoch 44/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0199 - accuracy: 0.9942 - f1_m: 0.9957 - precision_m: 0.9960 - recall_m: 0.9967 - val_loss: 1.0430 - val_accuracy: 0.7059 - val_f1_m: 0.7582 - val_precision_m: 0.8902 - val_recall_m: 0.7118
# Epoch 45/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0468 - accuracy: 0.9815 - f1_m: 0.9843 - precision_m: 0.9845 - recall_m: 0.9893 - val_loss: 1.1542 - val_accuracy: 0.7010 - val_f1_m: 0.7689 - val_precision_m: 0.8484 - val_recall_m: 0.7524
# Epoch 46/50
# 164/164 [==============================] - 10s 60ms/step - loss: 0.0626 - accuracy: 0.9799 - f1_m: 0.9662 - precision_m: 0.9698 - recall_m: 0.9648 - val_loss: 1.2271 - val_accuracy: 0.6373 - val_f1_m: 0.6906 - val_precision_m: 0.8236 - val_recall_m: 0.6472
# Epoch 47/50
# 164/164 [==============================] - 10s 60ms/step - loss: 0.0171 - accuracy: 0.9928 - f1_m: 0.9948 - precision_m: 0.9998 - recall_m: 0.9911 - val_loss: 1.1940 - val_accuracy: 0.7892 - val_f1_m: 0.8513 - val_precision_m: 0.8329 - val_recall_m: 0.8967
# Epoch 48/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0049 - accuracy: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 1.0478 - val_accuracy: 0.7549 - val_f1_m: 0.8250 - val_precision_m: 0.8431 - val_recall_m: 0.8407
# Epoch 49/50
# 164/164 [==============================] - 10s 60ms/step - loss: 0.0610 - accuracy: 0.9829 - f1_m: 0.9711 - precision_m: 0.9712 - recall_m: 0.9717 - val_loss: 0.9476 - val_accuracy: 0.7892 - val_f1_m: 0.8548 - val_precision_m: 0.8455 - val_recall_m: 0.9118
# Epoch 50/50
# 164/164 [==============================] - 10s 59ms/step - loss: 0.0480 - accuracy: 0.9890 - f1_m: 0.9912 - precision_m: 0.9900 - recall_m: 0.9949 - val_loss: 0.8124 - val_accuracy: 0.7745 - val_f1_m: 0.8083 - val_precision_m: 0.8732 - val_recall_m: 0.7980

# %%
# %ls
# Out:
# gdrive/               save_at_Dan_32.h10/  save_at_Dan_5.h10/
# sample_data/          save_at_Dan_32.h5    save_at_Dan_5.h5
# save_at_Dan_100.h10/  save_at_Dan_33.h10/  save_at_Dan_60.h10/
# save_at_Dan_10.h10/   save_at_Dan_33.h5    save_at_Dan_61.h10/
# save_at_Dan_10.h5     save_at_Dan_34.h10/  save_at_Dan_62.h10/
# save_at_Dan_11.h10/   save_at_Dan_34.h5    save_at_Dan_63.h10/
# save_at_Dan_11.h5     save_at_Dan_35.h10/  save_at_Dan_64.h10/
# save_at_Dan_12.h10/   save_at_Dan_35.h5    save_at_Dan_65.h10/
# save_at_Dan_12.h5     save_at_Dan_36.h10/  save_at_Dan_66.h10/
# save_at_Dan_13.h10/   save_at_Dan_36.h5    save_at_Dan_67.h10/
# save_at_Dan_13.h5     save_at_Dan_37.h10/  save_at_Dan_68.h10/
# save_at_Dan_14.h10/   save_at_Dan_37.h5    save_at_Dan_69.h10/
# save_at_Dan_14.h5     save_at_Dan_38.h10/  save_at_Dan_6.h10/
# save_at_Dan_15.h10/   save_at_Dan_38.h5    save_at_Dan_6.h5
# save_at_Dan_15.h5     save_at_Dan_39.h10/  save_at_Dan_70.h10/
# save_at_Dan_16.h10/   save_at_Dan_39.h5    save_at_Dan_71.h10/
# save_at_Dan_16.h5     save_at_Dan_3.h10/   save_at_Dan_72.h10/
# save_at_Dan_17.h10/   save_at_Dan_3.h5     save_at_Dan_73.h10/
# save_at_Dan_17.h5     save_at_Dan_40.h10/  save_at_Dan_74.h10/
# save_at_Dan_18.h10/   save_at_Dan_40.h5    save_at_Dan_75.h10/
# save_at_Dan_18.h5     save_at_Dan_41.h10/  save_at_Dan_76.h10/
# save_at_Dan_19.h10/   save_at_Dan_41.h5    save_at_Dan_77.h10/
# save_at_Dan_19.h5     save_at_Dan_42.h10/  save_at_Dan_78.h10/
# save_at_Dan_1.h10/    save_at_Dan_42.h5    save_at_Dan_79.h10/
# save_at_Dan_1.h5      save_at_Dan_43.h10/  save_at_Dan_7.h10/
# save_at_Dan_20.h10/   save_at_Dan_43.h5    save_at_Dan_7.h5
# save_at_Dan_20.h5     save_at_Dan_44.h10/  save_at_Dan_80.h10/
# save_at_Dan_21.h10/   save_at_Dan_44.h5    save_at_Dan_81.h10/
# save_at_Dan_21.h5     save_at_Dan_45.h10/  save_at_Dan_82.h10/
# save_at_Dan_22.h10/   save_at_Dan_45.h5    save_at_Dan_83.h10/
# save_at_Dan_22.h5     save_at_Dan_46.h10/  save_at_Dan_84.h10/
# save_at_Dan_23.h10/   save_at_Dan_46.h5    save_at_Dan_85.h10/
# save_at_Dan_23.h5     save_at_Dan_47.h10/  save_at_Dan_86.h10/
# save_at_Dan_24.h10/   save_at_Dan_47.h5    save_at_Dan_87.h10/
# save_at_Dan_24.h5     save_at_Dan_48.h10/  save_at_Dan_88.h10/
# save_at_Dan_25.h10/   save_at_Dan_48.h5    save_at_Dan_89.h10/
# save_at_Dan_25.h5     save_at_Dan_49.h10/  save_at_Dan_8.h10/
# save_at_Dan_26.h10/   save_at_Dan_49.h5    save_at_Dan_8.h5
# save_at_Dan_26.h5     save_at_Dan_4.h10/   save_at_Dan_90.h10/
# save_at_Dan_27.h10/   save_at_Dan_4.h5     save_at_Dan_91.h10/
# save_at_Dan_27.h5     save_at_Dan_50.h10/  save_at_Dan_92.h10/
# save_at_Dan_28.h10/   save_at_Dan_50.h5    save_at_Dan_93.h10/
# save_at_Dan_28.h5     save_at_Dan_51.h10/  save_at_Dan_94.h10/
# save_at_Dan_29.h10/   save_at_Dan_52.h10/  save_at_Dan_95.h10/
# save_at_Dan_29.h5     save_at_Dan_53.h10/  save_at_Dan_96.h10/
# save_at_Dan_2.h10/    save_at_Dan_54.h10/  save_at_Dan_97.h10/
# save_at_Dan_2.h5      save_at_Dan_55.h10/  save_at_Dan_98.h10/
# save_at_Dan_30.h10/   save_at_Dan_56.h10/  save_at_Dan_99.h10/
# save_at_Dan_30.h5     save_at_Dan_57.h10/  save_at_Dan_9.h10/
# save_at_Dan_31.h10/   save_at_Dan_58.h10/  save_at_Dan_9.h5
# save_at_Dan_31.h5     save_at_Dan_59.h10/

# %%
import numpy as np

path_model="./save_at_Dan_50.h5"
model.load_weights(path_model)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/gdrive/Shareddrives/ComED Codes and Data/Dataset/Images",
    seed=1337,
    image_size=image_size,
    batch_size=1,
)

count_test_samples = len(test_ds)
print("Count test data:", count_test_samples)


predict_prob = []
label_list = []
for i in range(count_test_samples):
    for image, label in test_ds.take(1):
        [[pred]] = model.predict(image)
        label_list.append(np.float32(label)[0])
        predict_prob.append(pred)
    # showing the test resluts
    if i == 8:
        print("predict_prob:", predict_prob)
        print("label_list:", label_list)
print("done!")
# Out:
# Found 1024 files belonging to 2 classes.
# Count test data: 1024
# predict_prob: [0.9927699, 0.99960846, 0.9996959, 0.0004220325, 0.9999504, 0.0004220325, 0.9927699, 0.9927699, 1.0]
# label_list: [1.0, 1.0, 1.0, 0.0, 1.0, 0.0, 1.0, 1.0, 1.0]
# done!

# %%
#ROC plots and similar
import matplotlib.pylab as plt

def get_roc(pred_prob,y_true):
    pos = y_true[y_true==1]
    neg = y_true[y_true==0]
    threshold = np.sort(pred_prob)[::-1]   
    y = y_true[pred_prob.argsort()[::-1]]
    tpr_all = [0] ; fpr_all = [0]
    tpr = 0 ; fpr = 0
    x_step = 1/float(len(neg))
    y_step = 1/float(len(pos))
    y_sum = 0                      
    for i in range(len(threshold)):
        if y[i] == 1:
            tpr += y_step
            tpr_all.append(tpr)
            fpr_all.append(fpr)
        else:
            fpr += x_step
            fpr_all.append(fpr)
            tpr_all.append(tpr)
            y_sum += tpr
    return tpr_all,fpr_all,y_sum*x_step


tpr_lr,fpr_lr,auc_lr = get_roc(np.array(predict_prob),np.array(label_list))  

plt.figure(figsize=(12,8))
plt.plot(fpr_lr,tpr_lr,label="AUC: {:.3f}".format(auc_lr),linewidth=2)
plt.xlim([-0.01,1.01])
plt.ylim([-0.01,01.01])
plt.plot([(0,0),(1,1)],'r--')
plt.xlabel("False Positive Rate",fontsize=16)
plt.ylabel("True Positive Rate",fontsize=16)
plt.title("ROC Curve",fontsize=16)
plt.legend(loc="lower right",fontsize=16)
plt.show()

# %%
# PR curve
def get_pr(pred_prob,y_true):
    pos = y_true[y_true==1]
    threshold = np.sort(pred_prob)[::-1]
    y = y_true[pred_prob.argsort()[::-1]]
    recall = [] ; precision = []
    tp = 0 ; fp = 0
    auc = 0
    for i in range(len(threshold)):
        if y[i] == 1:
            tp += 1
            recall.append(tp/len(pos))
            precision.append(tp/(tp+fp))
            auc += (recall[i]-recall[i-1])*precision[i]
        else:
            fp += 1
            recall.append(tp/len(pos))
            precision.append(tp/(tp+fp))
    return precision,recall,auc

precision_lr,recall_lr,auc_lr = get_pr(np.array(predict_prob),np.array(label_list))

plt.figure(figsize=(12,8))
plt.plot(recall_lr,precision_lr,linewidth=2)
plt.xlim([-0.01,1.01])
plt.ylim([-0.01,01.01])
plt.plot([(0,0),(1,1)],'r--')
plt.xlabel("Recall",fontsize=16)
plt.ylabel("Precision",fontsize=16)
plt.title("Precision Recall Curve",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Precision Recall Curve')

# %%
# confuse matrix
def get_conf_mat(pred_prob,y_true):
    TP,FP,FN,TN = 0,0,0,0
    num_label = pred_prob.shape[0]
    for i in range (num_label):
        if y_true[i] == 1 and pred_prob[i] > 0.5:
            TP += 1
        elif y_true[i] == 1 and pred_prob[i] < 0.5:
            FN += 1
        elif y_true[i] == 0 and pred_prob[i] < 0.5:
            TN += 1
        else:
            FP += 1

    return TP,FP,FN,TN

        
TP,FP,FN,TN = get_conf_mat(np.array(predict_prob),np.array(label_list))
conf_mat = [[TP,FP],[FN,TN]]
print("confuse_matrix:", conf_mat)
# Out:
# confuse_matrix: [[747, 0], [0, 277]]
